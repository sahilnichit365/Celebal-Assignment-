# %%
import pandas as pd
import zipfile
import os

# %%
zip_path = "archive.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("shopping_data")

print("ZIP file extracted successfully!")
# Out:
# ZIP file extracted successfully!

# %%
os.listdir("shopping_data")
# Out:
# ['backpacks.csv',
#  'bath-robe.csv',
#  'bath-towels.csv',
#  'bathroom-accessories.csv',
#  'bedsheets.csv',
#  'belts.csv',
#  'bodysuit.csv',
#  'boots.csv',
#  'boxers.csv',
#  'bra.csv',
#  'bracelet.csv',
#  'briefs.csv',
#  'camisoles.csv',
#  'candle-holders.csv',
#  'caps.csv',
#  'casual-shoes.csv',
#  'chair-cover.csv',
#  'clothing-set.csv',
#  'clutches.csv',
#  'co-ords.csv',
#  'Combined_dataset.csv',
#  'curtains-and-sheers.csv',
#  'cutlery.csv',
#  'dinnerware.csv',
#  'dresses.csv',
#  'duffel-bag.csv',
#  'dungarees.csv',
#  'dupatta.csv',
#  'earrings.csv',
#  'ethnic-dresses.csv',
#  'face-moisturisers.csv',
#  'face-wash-and-cleanser.csv',
#  'flats.csv',
#  'flip-flops.csv',
#  'floor-mats--dhurries.csv',
#  'formal-shoes.csv',
#  'foundation.csv',
#  'gloves.csv',
#  'hair-accessory.csv',
#  'hair-brush-and-comb.csv',
#  'hair-cream-and-mask.csv',
#  'hair-masks.csv',
#  'handbags.csv',
#  'headphones.csv',
#  'heels.csv',
#  'home-fragrance-set.csv',
# ...

# %%
df = pd.read_csv("shopping_data/Combined_dataset.csv")

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %%
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %%
print("Missing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100

print(missing_percent)
# Out:
# product_id                 0.0
# title                      0.0
# product_description        0.0
# rating                     0.0
# ratings_count              0.0
# initial_price              0.0
# discount                  12.1
# final_price                0.0
# currency                   0.0
# images                     0.0
# delivery_options           0.0
# product_details            0.0
# breadcrumbs                0.0
# product_specifications     0.0
# amount_of_stars            0.0
# what_customers_said       57.3
# seller_name               30.1
# sizes                      0.0
# videos                    78.1
# seller_information        30.1
# variations                56.2
# best_offer                 0.0
# more_offers                0.0
# category                   0.0
# dtype: float64

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
cat_cols = df.select_dtypes(include=['object', 'string']).columns

for col in cat_cols:
    if not df[col].mode().empty:
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
print(df.isnull().sum())
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

print("Duplicates Removed Successfully")
# Out:
# Duplicates Removed Successfully

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df[['title', 'category', 'initial_price', 'rating']].head()
# Out:
#             title   category  initial_price  rating
# 0     Lino Perros  backpacks           3995     3.8
# 1  Tommy Hilfiger  backpacks           2899     4.5
# 2           Lavie  backpacks           2999     4.4
# 3          F Gear  backpacks           1675     4.4
# 4       MYTRIDENT  bath-robe           2899     4.7

# %%
high_rated = df[df['rating'] > 4]

high_rated[['title', 'rating']].head(10)
# Out:
#              title  rating
# 1   Tommy Hilfiger     4.5
# 2            Lavie     4.4
# 3           F Gear     4.4
# 4        MYTRIDENT     4.7
# 5              H&M     4.5
# 7          My Room     4.7
# 8          My Room     4.5
# 10       MYTRIDENT     4.4
# 15    Home Ecstasy     4.5
# 17          Arrabi     4.3

# %%
import numpy as np

df['quantity'] = np.random.randint(1, 5, len(df))

df['total_amount'] = df['initial_price'] * df['quantity']

df[['initial_price', 'quantity', 'total_amount']].head()
# Out:
#    initial_price  quantity  total_amount
# 0           3995         2          7990
# 1           2899         3          8697
# 2           2999         2          5998
# 3           1675         4          6700
# 4           2899         2          5798

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...   seller_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                1000 non-null   float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df.to_csv("Cleaned_Shopping_Dataset.csv", index=False)

print("Cleaned_Shopping_Dataset saved successfully.")
# Out:
# Cleaned_Shopping_Dataset saved successfully.

# %%
import os

for file in os.listdir():
    if "Cleaned" in file:
        print(file)
# Out:
# Cleaned_Shopping_Dataset.csv

# %%
import os

print(os.path.abspath("Cleaned_Shopping_Dataset.csv"))
# Out:
# C:\Users\sahil nichit\Week_1 Celebal_Assignment\Cleaned_Shopping_Dataset.csv

# %%
# Summary

1. Loaded the shopping dataset using Pandas.
2. Explored the dataset using head(), shape(), columns, and info().
3. Identified and handled missing values using median and mode.
4. Removed duplicate records from the dataset.
5. Performed filtering and column selection operations.
6. Created a derived column (discount_amount/total_amount).
7. Saved the cleaned dataset as Cleaned_Shopping_Dataset.csv.

Conclusion:
The dataset was successfully cleaned and prepared for further analysis.
# Out:
#   Cell In[28], line 3
#     1. Loaded the shopping dataset using Pandas.
#        ^
# SyntaxError: invalid syntax
